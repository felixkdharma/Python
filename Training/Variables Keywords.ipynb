# %%
# ## KEYWORDS AND VARIABLES
# ## Keywords a special reserved words which convey a special meaning to interpreter or compiler.
# ## Variables are used to store data values.

# %%
a = "Felix Kurniawan Dharma"
print(a)

# "" is String Variable
# 1,2,3 is Integer Variable
# 1.5, 2.5 is Float Variable
# Out:
# Felix Kurniawan Dharma

# %%
def sum_fun(a,b):
    return a + b

# %%
sum_fun(5,10)
# Out:
# 15
