# %%
#Numeric has 3 child classes which are int, float, and complex number
#Sequnces has 3 child classes which are list, tuple, and strings
#Strings are immutable whereas lists and tuples are mutable. that means you cannot change a character in a string

# %%
#Input and Output Example
name = input("Enter your name: ")
print("Hello, " + name)
# Out:
# Hello, 12

# %%
#Typecasting

x = 4.6
x_casted = int(x)
print(x_casted)  # Output: 4

# %%
name = "Feli"
name = "Felix" #reassigning variable to change the value
print(name)

# %%
## Operator Mathematics Examples
## ** is for exponentiation
## // is for floor division
## % is for modulus

a = 2**5
b = 27//4
c = 27%4

print(a)
print(b)
print(c)
